# %% [markdown]
# <div class="alert alert-info"><big><b>Комментарий ревьюера</b></big><br>Привет, Александр! 👋<br><br> Ничего не поменялось, меня всё ещё зовут Дмитрий Кирсанов. <br><br>Комментарии всё ещё обозначены пометкой <b>Комментарий ревьюера</b> и всё ещё содержат описание <br><span class="alert-success">✔️ хорошего, 👍 отличного, 📝 советов</span>,&nbsp;&nbsp;<span class="alert-warning">📌 важного, ⚠️ замечаний, 💡 рекомендаций</span>,&nbsp;&nbsp;<span class="alert-danger">🔧 доработок, 🚫 ошибок или 👀 вопросов.</span><br><br>После того, как замечание будет устранено, я сменю красный цвет на жёлтый, чтобы тебе было удобнее выделять те места, которые требуют доработки. Код, которым я предлагаю выделять твои комментарии<!--
# НЕ НАДО КОПИРОВАТЬ КОД, ПРИ ПОМОЩИ КОТОРОГО Я ВЫВОЖУ КОД-->:<br><code>&lt;div class=&quot;alert btn-primary&quot;&gt;&lt;b&gt;Комментарий студента:&lt;/b&gt;&lt;br&gt;   Ок   &lt;/div&gt;</code><br><!--
# КОПИРОВАТЬ НАДО, КОГДА ВИДЕН ОФОРМЛЕННЫЙ ТЕКСТ-->Всё ещё просьба задавать вопросы и описывать изменения в проект.</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Привет, Дмитрий! Спасибо большое за проделанную работу по ревью и твои комментарии. Я внёс необходимые правки по красным комментариям. </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;📌<br>
# Презентацию пришли, пожалуйста, с дашбордом.
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2</b>&nbsp;✔️<br>
# Титульный лист презентации должен быть оформлен так, чтобы на неё было удобно сослаться. В самой презентации не нужно мельчить и нужно снабжать графики тезисами. У вас должны быть упомянуты все характеристики и в визуально наглядном виде представлены не только результаты работы (сформированные сегменты и рекомендации), но и ход ваших мыслей, почему именно эти характеристики вы взяли и именно так, а другие не взяли. Обязательно указываем типичного отточного, подчёркиваем чем он отличается от типичного неотточного, что сравнивали стат.гипотезами; результаты корреляционного анализа читаемо; уровни оттока по категориальным характеристикам; как поняли что непрерывные нужно разделить именно так, как разделили.
# </div>

# %% [markdown]
# # Финальный проект. Анализ оттока клиентов Метанпром банка

# %% [markdown]
# ###  Описание проекта

# %% [markdown]
# #### Описание кейса и цель

# %% [markdown]
# Цель проекта - анализ оттока клиентов банка. Анализ должен показать какие сегменты клиентов склонны уходить из банка и дать рекомендации отделу маркетинга.

# %% [markdown]
# Заказчик : Отдел маркетинга.
#
# Кому нужна информация? : Информация нужна менеджеру, который занимается маркетиновыми кампаниями и работает в тесной связке с менеджерами продуктов.
#
# Что хотят получить?: Максимально эффективно выделить сегменты отточных клиентов, чтобы они были однородными, высокоотточными и покрывали максимум проблемных зон банка. Таким образом, маркетинговое воздействие на эти сегменты должно привести к уменьшению.
#
# Почему возникла потребность проводить исследования? В банке последнее время драматически повысился отток, это начинает становиться проблемой, которая угрожает существованию банка.
#
# Проводили ли ранее такие исследования?: Раньше проводилось исследование и по нему был составлен дашборд, но он устарел и по нему сейчас не ясно, в чём сейчас заключается проблема и как её можно решать.
# Состав клиентов банка изменился и старые сегменты больше не подходят.

# %% [markdown]
# #### Описание данных

# %% [markdown]
# Датасет содержит данные о клиентах банка «Метанпром». Банк располагается в Ярославле и областных городах: Ростов Великий и Рыбинск.
#
# Колонки:
#
# - `userid` — идентификатор пользователя,
# - `score` — баллы кредитного скоринга,
# - `City` — город,
# - `Gender` — пол,
# - `Age` — возраст,
# - `equity`  — количество баллов собственности
# - `Balance` — баланс на счёте,
# - `Products` — количество продуктов, которыми пользуется клиент,
# - `CreditCard` — есть ли кредитная карта,
# - `last_activity` — активный клиент,
# - `estimated_salary` — заработная плата клиента,
# - `Churn` — ушёл или нет.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 0</b>&nbsp;✔️ описали сам проект<br>

# %% [markdown]
# #### Декомпозиция

# %% [markdown]
# 1. Загрузка данных и первичный обзор датасета.
# 2. Предобработка данных.
# 3. Исследовательский анализ данных.
# 4. Формулировка и проверка статистических гипотез.
# 5. Сегментация.
# 6. Выводы и рекомендации.

# %% [markdown]
# ### Загружаем данные и изучаем общую информацию

# %% [markdown]
# #### Импорт библиотек и загрузка данных

# %%
# импорт библиотек

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
#
# ! [image.png](attachment:image.png)
#
# Я заметил что первая ячейка имеет номер выполнения, отличный от <tt>[1]</tt>. Это может приводить к тому, что не вызовут ошибку какие-то изменения кода, которые вызвали бы ошибку после перезапуска ноутбука (или при его запуске на другой машине), например потому, что в памяти сохраняются переменные, которые были сформированы до того, как код был изменён. Поэтому важно выполнять ячейки с первой по последнюю строго последовательным образом перед тем, как отправлять их кому-то.
# </div>
#
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;📝<br>
# Хорошо, что в начале работы помещаешь описание проекта, это позволит читателям быстро понять, о чём работа.
#
# Импорт библиотек в самом начале позволит быстро понять, какое окружение нужно для ноутбука. Такой код проще поддерживать.
#
# Если ты не используешь потом какие-то библиотеки или методы, их импорт можно закомментировать. Если передумаешь, то сможешь убрать пометки комментирования и всё снова заработает.
#
# <a href='https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html'>Материал по импорту.</a> Также есть простые правила — не стоит импортировать дважды одно и то же, желательно разбивать импорт на группы (отделять друг от друга переносами строк и комментариями), при этом импорт <a href='https://docs.python.org/3/library/index.html'>стандартных библиотек</a> стоит размещать в начале.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Принято! Обычно так и делаю, в этот раз что-то намудрил. </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %%
# чтение файла

path = "https://drive.google.com/uc?export=download&id=1-U61mhTz_N1ARjy2XSAZ7IlQqGjeqP0F"

try:
    df = pd.read_csv(path)
except:
    print('Ошибка загрузки данных!')
else:
    print('Данные загружены успешно!')
# Out:
# Данные загружены успешно!

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;📝<br>
# Можно загружать файлы, заранее проверяя методами <tt>os.path.isfile</tt> или <tt>os.path.exists</tt> существование файла. Для путей в интернете этот метод не годится.
#
# При использовании конструкции try-except важно «отлавливать» конкретный вид ошибки, возникновение которой ты ожидаешь. Название ошибки обычно написано с заглавной буквы красным цветом в конце сообщения об ошибке. Немного <a href='https://tonais.ru/file/oshibka-filenotfounderror-python'>подробнее</a> об этом.
# </div>

# %% [markdown]
# #### Первичный обзор данных

# %%
# вывод информации о датафрейме

df.sample(7)
# Out:
#       USERID  score       city gender   age  equity     balance  products  \
# 2880  224208  807.0    Рыбинск      Ж  55.0       3   284771.28         2
# 7453  210627  864.0  Ярославль      Ж  38.0       4  1527225.32         4
# 4109  141289  891.0  Ярославль      Ж  33.0       3   446111.25         3
# 567   195735  838.0  Ярославль      М  37.0       5  1245476.31         2
# 4670  214963  805.0    Рыбинск      М  25.0       4   212161.48         1
# 2969  154608  853.0    Рыбинск      Ж  51.0       3   926278.14         2
# 5379  126217  869.0  Ярославль      М  42.0       4   241345.76         1
#
#       credit_card  last_activity  EST_SALARY  churn
# 2880            1              1    87899.19      0
# 7453            1              1   162999.17      1
# 4109            0              1   171380.32      1
# 567             0              1   182952.19      0
# 4670            1              1    31505.32      0
# 2969            0              0    94887.37      0
# ...

# %% [markdown]
# userid — идентификатор пользователя,
# score — баллы кредитного скоринга,
# City — город,
# Gender — пол,
# Age — возраст,
# Objects — количество объектов в собственности / equity — количество баллов собственности
# Balance — баланс на счёте,
# Products — количество продуктов, которыми пользуется клиент,
# CreditCard — есть ли кредитная карта,
# Loyalty / last_activity — активный клиент,
# estimated_salary — заработная плата клиента,
# Churn — ушёл или нет.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   USERID         10000 non-null  int64
#  1   score          10000 non-null  float64
#  2   city           10000 non-null  object
#  3   gender         10000 non-null  object
#  4   age            9974 non-null   float64
#  5   equity         10000 non-null  int64
#  6   balance        7705 non-null   float64
#  7   products       10000 non-null  int64
#  8   credit_card    10000 non-null  int64
#  9   last_activity  10000 non-null  int64
#  10  EST_SALARY     10000 non-null  float64
#  11  churn          10000 non-null  int64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# 1. приведем наименования полей USERID, EST_SALARY к принятому виду
# 2. приведем типы данных полей score и age к int64
# 3. надо понять природу пропусков age, balance

# %%
print(f"{df.shape[0]} записей в базе представлено, {df.shape[1]} признаков всего, из них \
\nкатегориальные признаки: {list(df.select_dtypes(include=['object']).columns)}")
# Out:
# 10000 записей в базе представлено, 12 признаков всего, из них
# категориальные признаки: ['city', 'gender']

# %%
print(f"В базе представлены следующие города {df['city'].unique()}, клиенты следующих полов {df['gender'].unique()}")
# Out:
# В базе представлены следующие города ['Рыбинск' 'Ярославль' 'Ростов'], клиенты следующих полов ['Ж' 'М']

# %%
print(f"Всего в базе {df['USERID'].nunique()} уникальных идентификаторов при 10000 записей")
# Out:
# Всего в базе 9927 уникальных идентификаторов при 10000 записей

# %% [markdown]
# Получается, что есть идентификаторы, которые встречаются в базе более одного раза. Посмотрим на них при анализе явных и неявных дубликатов.

# %%
df.describe()
# Out:
#              USERID         score          age        equity       balance  \
# count   10000.00000  10000.000000  9974.000000  10000.000000  7.705000e+03
# mean   171814.71260    848.699400    42.734409      2.627600  8.277943e+05
# std     33708.23812     65.448519    12.179971      1.980836  1.980614e+06
# min     94561.00000    642.000000    18.000000      0.000000  0.000000e+00
# 25%    142810.25000    802.000000    33.000000      0.000000  2.955542e+05
# 50%    172728.00000    853.000000    40.000000      3.000000  5.242722e+05
# 75%    201261.75000    900.000000    51.000000      4.000000  9.807058e+05
# max    229145.00000   1000.000000    86.000000      9.000000  1.191136e+08
#
#            products   credit_card  last_activity    EST_SALARY         churn
# count  10000.000000  10000.000000   10000.000000  1.000000e+04  10000.000000
# mean       1.870100      0.680400       0.523500  1.478669e+05      0.182000
# ...

# %% [markdown]
# 1. score - медиана практически не отличается от среднего, на первый взгляд с кредитным скорингом все в порядке. Минимальное значение 642, максимальное 1000.
# 2. age - от 18 до 86 лет, в норме
# 3. equity - количество баллов собственности - от 0 до 9, в норме
# 4. balance - очевидно есть выбросы в обе стороны, предварительно это ок - будем смотреть на их поведение тоже
# 5. products - 0 вызывает вопросы, какой это тогда клиент банка? может стоит удалить из базы таких, посмотрим дальше сколько таких
# 6. credit_card - 1=есть или 0=нет, все ок, у 68% она есть
# 7. last_activity - 1=активный или 0=неактивный клиент
# 8. EST_SALARY - вызывает вопросы минимальная зп 2500рубрей - надо посмотреть внимательнее, по идее не должно быть меньше МРОТ = 16242 рублей
# 9. churn - 1=отточный или 0=неотточный, в среднем каждый пятый клиент отточный

# %%
# посмотрим на статистику по пустым значениям

pd.DataFrame(df.isna().mean()*100).sort_values(by=0)[::-1].style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_94b62_row0_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_94b62_row1_col0{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_94b62_row2_col0,#T_94b62_row3_col0,#T_94b62_row4_col0,#T_94b62_row5_col0,#T_94b62_row6_col0,#T_94b62_row7_col0,#T_94b62_row8_col0,#T_94b62_row9_col0,#T_94b62_row10_col0,#T_94b62_row11_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_94b62_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94b62_level0_row0" class="row_heading level0 row0" >balance</th>
#                         <td id="T_94b62_row0_col0" class="data row0 col0" >22.950000</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# 23% пропусков в поле balance (почти 2300 записей из 10000) - изучим зависимости
#
# и менее 1% по возрасту (26 записей из 10000) - их можно удалять смело

# %% [markdown]
# #### Промежуточный вывод по первичному анализу данных

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
#
#     Данные загружены успешно.
#
#     В нашем распоряжении есть датасет, состоящий из 10 000 уникальных записей о клиентах Метанпромбанка, со следующей информацией:
#
#     1. userid - уникальный идентификатор пользователя (иногда встречается более одного раза в базе, по идее идентификатор присваивается при каждом внесении в базу, т.е. теоретически у одного человек может быть два разных id)
#     2. score - медиана практически не отличается от среднего -  на первый взгляд с кредитным скорингом все в порядке. Минимальное значение 642, максимальное 1000 - можно предположить, что используется система от 600 до 1000 (хотя обычно применяют от 300 до 850).
#     3. city - данные по трём городам - 'Рыбинск' 'Ярославль' 'Ростов'
#     4. gender - мужской и женский
#     5. age - от 18 до 86 лет
#     6. equity - количество баллов собственности от 0 до 9
#     7. balance - очевидно есть выбросы в обе стороны, предварительно это ок - посмотрим более подробно дальше
#     8. products - количество продуктов, которыми пользуется клиент - от 0 до 5. Ноль продуктов вызывает вопросы, какой это тогда клиент банка? Может стоит удалить из базы таких.
#     9. credit_card - есть ли кредитная карта, все ок, у 68% она есть.
#     10. last_activity - активный клиент, 0 или 1.
#     11. EST_SALARY - вызывает вопросы минимальная зп 2500 рубрей - надо посмотреть внимательнее, по идее не должно быть меньше 16242 (МРОТ)
#     12. churn - ушёл или нет, 0 или 1.
#
#
#
#     В предобработке следует сделать следующее:
#
#         1. Переименовать столбцы 'USERID':'user_id', 'EST_SALARY':'est_salary'.
#         2. Привести типы полей 'score', 'age' к int64.
#         3. Понять природу 23% пропусков в 'balance'.
#         4. Удалить 26 записей с пропусками в 'age'.
#         5. Обработать дубликаты и посмотреть повторы в user_id.
#         6. Обработать клиентов без продуктов.
#         7. Изучить минимальные зарплаты.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обработка названий столбцов

# %%
# приведем названия столбцов к нормальному виду

df = df.rename(columns = {'USERID':'user_id', 'EST_SALARY':'est_salary'})
display(df.sample(2))
# Out:
#       user_id  score    city gender   age  equity    balance  products  \
# 5476   192399  757.0  Ростов      М  42.0       2  263384.84         2
# 6420   156577  871.0  Ростов      Ж  66.0       5  866837.09         2
#
#       credit_card  last_activity  est_salary  churn
# 5476            1              1   183836.66      0
# 6420            0              0    48439.30      0

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;📝<br>
# Удобно для такого пользоваться векторными версиями функций через <a href='https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html'>строковый ацессор</a> pandas, например lower
# </div>

# %% [markdown]
# #### Исследование пропущенных значений

# %%
# посмотрим на записи, где 0 продуктов

df[df['products']==0]
# Out:
#       user_id  score     city gender   age  equity  balance  products  \
# 8957   147837  962.0  Рыбинск      Ж  79.0       3      NaN         0
#
#       credit_card  last_activity  est_salary  churn
# 8957            0              0    25063.96      1

# %%
# такая запись всего одна - удалим её

df = df[df['products']!=0]

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>✔️</big></b></div>

# %%
# посмотрим на записи, где не указан возраст

df[df.age.isna()]
# Out:
#       user_id  score       city gender  age  equity     balance  products  \
# 1247   228075  932.0  Ярославль      М  NaN       5  7601719.20         2
# 2165   187635  692.0    Рыбинск      Ж  NaN       0         NaN         1
# 2444   221156  913.0  Ярославль      М  NaN       0         NaN         1
# 3091   138660  836.0     Ростов      Ж  NaN       5   294315.53         2
# 4912   210674  834.0    Рыбинск      М  NaN       1   238330.52         2
# 5470   218868  827.0    Рыбинск      Ж  NaN       4   448959.07         2
# 5495   151662  884.0    Рыбинск      Ж  NaN       0         NaN         1
# 7236   210135  908.0    Рыбинск      Ж  NaN       4  1120340.31         3
# 7248   219343  920.0    Рыбинск      Ж  NaN       0         NaN         1
# 7345   184913  829.0  Ярославль      Ж  NaN       3   188648.77         2
# 7409   214031  777.0  Ярославль      М  NaN       2   171510.23         1
# 8015   198635  670.0  Ярославль      Ж  NaN       0         NaN         1
# ...

# %%
# удалим записи, где не указан возраст

df = df[~df.age.isna()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9973 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        9973 non-null   int64
#  1   score          9973 non-null   float64
#  2   city           9973 non-null   object
#  3   gender         9973 non-null   object
#  4   age            9973 non-null   float64
#  5   equity         9973 non-null   int64
#  6   balance        7695 non-null   float64
#  7   products       9973 non-null   int64
#  8   credit_card    9973 non-null   int64
#  9   last_activity  9973 non-null   int64
#  10  est_salary     9973 non-null   float64
#  11  churn          9973 non-null   int64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 1012.9+ KB

# %% [markdown]
# Изучим, как строки с пропусками в 'balance' зависят от имеющихся данных. 23% это много, удалять точно нельзя, но и заменять на среднее значение по категориям тоже может быть не верно - надо сначала изучить зависимости.

# %%
print(f"Всего {df['balance'].isna().sum()} пропусков в поле 'balance'")
# Out:
# Всего 2278 пропусков в поле 'balance'

# %%
# добавим столбец, в котором 1=баланс указан, 0=пропуск в поле баланс
df['debit_card'] = df['balance'].copy() 
df.loc[(~df['debit_card'].isna()), 'debit_card'] = 1
df.loc[(df['debit_card'].isna()), 'debit_card'] = 0

display(df.groupby('debit_card').mean())
# Out:
#                   user_id      score        age    equity        balance  \
# debit_card
# 0.0         171915.451273  865.31475  42.076822  0.050044            NaN
# 1.0         171710.892268  843.74412  42.924366  3.394802  827245.587515
#
#             products  credit_card  last_activity     est_salary     churn
# debit_card
# 0.0         1.163740     0.815628       0.549166  226433.776313  0.005268
# 1.0         2.081222     0.640156       0.515140  124520.394264  0.234698

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>👍</big></b> сравнили средние
#
# (правда более правильно сначала закодировать численно строковые характеристики - тут это пол и города)</div>

# %% [markdown]
# Из данной таблицы видны следующие особенности датасета с пропусками в поле 'balance' относительно записей, где таких пропусков нет:
#
# - средняя оценка собственности значительно меньше (у 95% клиентов без баланса на счету оценка собственности равна нулю)
# - в среднем один продукт, тогда так у клиентов без пропусков их 2
# - при этом зарплата в среднем выше почти в два раза
# - и последнее: такие клиенты не попадают в отток, практически к 100% случаях. Я думаю это самый важный вывод для нашего анализа, т.к. нам интересны именно отточные клиенты.

# %%
# Выясним, связаны ли пропуски в столбце balance с фактом оттока клиента из банка:

df[df['balance'].isna()]['churn'].value_counts()
# Out:
# 0    2266
# 1      12
# Name: churn, dtype: int64

# %% [markdown]
# Подтверждаем, что клиенты без указанного баланса почти в полном объеме остаются с банке

# %%
df[df['balance'].isna()]['last_activity'].value_counts()
# Out:
# 1    1251
# 0    1027
# Name: last_activity, dtype: int64

# %% [markdown]
# По активности разницы нет

# %%
df[df['balance'].isna()]['city'].value_counts()
# Out:
# Ярославль    1458
# Рыбинск       585
# Ростов        235
# Name: city, dtype: int64

# %% [markdown]
# Пропуски баланса встречаются для клиентов из всех трёх городов, но чаще всего у Ярославцев.

# %%
df[df['balance'].isna()]['credit_card'].value_counts()
# Out:
# 1    1858
# 0     420
# Name: credit_card, dtype: int64

# %% [markdown]
# У большинства таких клиентов есть кредитная карта.

# %% [markdown]
# Можно проедположить, что пропуски в балансе - это MNAR.
# Скорее всего это клиенты без активных дебетовых карт (тем более, что мы не знаем какие продукты подразумеваются в поле 'products').
# Для последующего исследовательского анализ заменим значения пропуски на нули.

# %%
# заменим пропуски на нули

df['balance'].replace(np.nan, 0, inplace=True)

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>✔️</big></b> Аргументированная замена.</div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;🔧<br>При наличии большого количества пропусков в датасете мы должны их исследовать и попробовать установить их тип, чтобы понять, можно ли их заполнять и как.
#
# Прошу воздерживаться от замены пропусков заглушкой — для численных столбцов это приводит к необходимости затем каждый раз при обращении к столбцу фильтровать данные и не несёт положительных последствий для анализа.
#
# Если пропуски относятся к типу MAR, то мы можем заменить их средними по группам связаных с пропусками и самим балансам показателей, если они относятся к типу MNAR, то замены возможны только с наличием непротиворечащей данным гипоезе о том, чем данные пропуски вызваны.
# </div><div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;📌<br> В рамках дизайн-ориентированного подхода к пропущенным данным аналитики, которые имеют доступ к информации о том, как собирались данные, оценивают пропуски на отношение к одной из трёх категорий: <ul>
# <li>MCAR (Missing Completely At Random / Отсутствует совершенно случайно) — пропуски не зависят от переменных и не ведут к систематической ошибке (смещение, bias), но увеличивают случайную ошибку (разброс, variance), можно их отбрасывать или заполнять, т.к. заполнение не повлияет на характер связи между заполняемой переменной и остальными.</li>
# <li>MAR (Missing At Random / Отсутствует случайно) — в рамках каждой из групп, которая есть в описываемой данными совокупности, распределение пропусков случайно, можно их отбрасывать.</li>
# <li>MNAR (Missing Not At Random / Отсутствует не случайно) — пропуски зависят от переменных, которых нет в данных, объяснить взаимосвязи с данными не получается, без дополнительного обоснования их нельзя отбрасывать или заполнять одним значением, т.к. это приведёт к заметным искажениям.</li></ul>
#
# Эта классификация пропусков давалась в дополнительных материалах. Мы должны выяснить, к какому типу относятся пропуски до того, как что-то с ними сделаем. Стоит изучить, как строки с пропусками зависят от имеющихся данных и поступать с ними исходя из этого.
# </div>

# %% [markdown]
# #### Преобразование типов данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9973 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        9973 non-null   int64
#  1   score          9973 non-null   float64
#  2   city           9973 non-null   object
#  3   gender         9973 non-null   object
#  4   age            9973 non-null   float64
#  5   equity         9973 non-null   int64
#  6   balance        9973 non-null   float64
#  7   products       9973 non-null   int64
#  8   credit_card    9973 non-null   int64
#  9   last_activity  9973 non-null   int64
#  10  est_salary     9973 non-null   float64
#  11  churn          9973 non-null   int64
#  12  debit_card     9973 non-null   float64
# dtypes: float64(5), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df[['score', 'age']] = df[['score', 'age']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9973 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        9973 non-null   int64
#  1   score          9973 non-null   int64
#  2   city           9973 non-null   object
#  3   gender         9973 non-null   object
#  4   age            9973 non-null   int64
#  5   equity         9973 non-null   int64
#  6   balance        9973 non-null   float64
#  7   products       9973 non-null   int64
#  8   credit_card    9973 non-null   int64
#  9   last_activity  9973 non-null   int64
#  10  est_salary     9973 non-null   float64
#  11  churn          9973 non-null   int64
#  12  debit_card     9973 non-null   float64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Обработка низких зарплат

# %%
low_salary = df[df['est_salary'] < 16242]
low_salary.sample(5)
# Out:
#       user_id  score       city gender  age  equity    balance  products  \
# 1753   161271    836  Ярославль      Ж   19       4    7703.05         4
# 443    207658    875  Ярославль      Ж   76       5  676450.87         3
# 8783   114221    948  Ярославль      Ж   26       1   77092.89         1
# 1520   207521    819    Рыбинск      М   63       4  597930.59         2
# 7351   180475    811  Ярославль      М   28       2  137191.95         2
#
#       credit_card  last_activity  est_salary  churn  debit_card
# 1753            1              1     5043.14      0         1.0
# 443             0              1    11319.50      0         1.0
# 8783            1              0     2546.30      0         1.0
# 1520            0              1    10677.73      0         1.0
# 7351            1              0    11353.22      0         1.0

# %%
print(f"{low_salary['user_id'].count()} записей содержат информацию с зарплатой менее МРОТ (16242 рублей)")
# Out:
# 80 записей содержат информацию с зарплатой менее МРОТ (16242 рублей)

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>
# На вводной встрече говорил, что это не обязательно зарплата, может быть какие-то другие регулярные доходы
# </div>

# %%
low_salary.describe()
# Out:
#              user_id       score        age     equity       balance  \
# count      80.000000   80.000000  80.000000  80.000000  8.000000e+01
# mean   175658.675000  817.300000  44.812500   3.150000  3.127972e+05
# std     31012.568529   52.829173  21.278202   1.684629  3.176077e+05
# min     95627.000000  725.000000  19.000000   0.000000  7.300000e+01
# 25%    148267.750000  784.750000  25.000000   2.000000  1.107684e+05
# 50%    176114.000000  813.500000  34.500000   3.000000  2.238856e+05
# 75%    200541.500000  836.750000  67.000000   4.000000  3.699157e+05
# max    228620.000000  984.000000  77.000000   7.000000  1.457259e+06
#
#         products  credit_card  last_activity    est_salary      churn  \
# count  80.000000    80.000000      80.000000     80.000000  80.000000
# mean    2.100000     0.700000       0.525000  12399.785500   0.062500
# std     0.722163     0.461149       0.502525   3321.940377   0.243589
# ...

# %% [markdown]
# В среднем такие клиенты имеют на счетах около 300000 т.р. и 2 банковских продукта. Возможно эти суммы ниже МРОТ являются социальными выплатами - пенсиями, стипендиями и т.п. Таких записей немного, существенного влияния на анализ они оказать не должны - оставим как есть

# %% [markdown]
# #### Исследование дубликатов

# %%
# проверим наличие полных дубликатов

print(f'Количество полных дубликатов: {df.duplicated().sum()}')
# Out:
# Количество полных дубликатов: 0

# %%
# найдем дубликаты в поле user_id:

print(f"{df['user_id'].duplicated().sum()} дубликатов в поле user_id")
# Out:
# 50 дубликатов в поле user_id

# %%
# удаление дубликатов

df.drop_duplicates(subset=['user_id'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9923 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        9923 non-null   int64
#  1   score          9923 non-null   int64
#  2   city           9923 non-null   object
#  3   gender         9923 non-null   object
#  4   age            9923 non-null   int64
#  5   equity         9923 non-null   int64
#  6   balance        9923 non-null   float64
#  7   products       9923 non-null   int64
#  8   credit_card    9923 non-null   int64
#  9   last_activity  9923 non-null   int64
#  10  est_salary     9923 non-null   float64
#  11  churn          9923 non-null   int64
#  12  debit_card     9923 non-null   float64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Добавление столбцов - кодирование городов и пола

# %%
# создадим копии столбцов city и gender:

df['city_']=df['city']
df['gender_']=df['gender']
df.head()
# Out:
#    user_id  score       city gender  age  equity     balance  products  \
# 0   183012    850    Рыбинск      Ж   25       1    59214.82         2
# 1   146556    861    Рыбинск      Ж   37       5   850594.33         3
# 2   120722    892    Рыбинск      Ж   30       0        0.00         1
# 3   225363    866  Ярославль      Ж   51       5  1524746.26         2
# 4   157978    730  Ярославль      М   34       5      174.00         1
#
#    credit_card  last_activity  est_salary  churn  debit_card      city_  \
# 0            0              1    75719.14      1         1.0    Рыбинск
# 1            1              0    86621.77      0         1.0    Рыбинск
# 2            1              1   107683.34      0         0.0    Рыбинск
# 3            0              1   174423.53      1         1.0  Ярославль
# 4            1              0    67353.16      1         1.0  Ярославль
#
#   gender_
# 0       Ж
# 1       Ж
# 2       Ж
# 3       Ж
# 4       М

# %%
df = pd.get_dummies(df, columns = ['gender_', 'city_'])

# %%
df = df.rename (
    columns = ({
        'city__Ростов':'Ростов', 'city__Рыбинск':'Рыбинск','city__Ярославль':'Ярославль', 
        'gender__Ж':'female', 'gender__М':'male'}))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9923 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        9923 non-null   int64
#  1   score          9923 non-null   int64
#  2   city           9923 non-null   object
#  3   gender         9923 non-null   object
#  4   age            9923 non-null   int64
#  5   equity         9923 non-null   int64
#  6   balance        9923 non-null   float64
#  7   products       9923 non-null   int64
#  8   credit_card    9923 non-null   int64
#  9   last_activity  9923 non-null   int64
#  10  est_salary     9923 non-null   float64
#  11  churn          9923 non-null   int64
#  12  debit_card     9923 non-null   float64
#  13  female         9923 non-null   uint8
#  14  male           9923 non-null   uint8
#  15  Ростов         9923 non-null   uint8
#  16  Рыбинск        9923 non-null   uint8
# ...

# %%
df.sample(10)
# Out:
#       user_id  score       city gender  age  equity    balance  products  \
# 7449   147377    971     Ростов      Ж   31       4  250150.45         1
# 8821   136071    822  Ярославль      Ж   48       3  676185.42         1
# 4861   181682    911  Ярославль      М   28       0       0.00         1
# 4898   117404    877  Ярославль      Ж   29       7  394906.70         3
# 3240   220733    886  Ярославль      Ж   42       3  416816.52         2
# 5996   180877    925  Ярославль      Ж   44       0       0.00         1
# 8009   171082    760    Рыбинск      М   34       5  585999.56         2
# 3539   162868    739  Ярославль      Ж   38       0       0.00         1
# 6964   200833    755  Ярославль      М   32       5  693151.87         3
# 795    135345    878    Рыбинск      Ж   36       3  801553.22         2
#
#       credit_card  last_activity  est_salary  churn  debit_card  female  male  \
# 7449            0              0    41876.19      1         1.0       1     0
# ...

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>👍</big></b></div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;📝<br>
# Категориальные данные <a href='https://discover6sigma.org/post/2011/06/desc-stats/'>делятся на</a> упорядоченные (уровень образования, удовлетворённости пользователя) и неупорядоченные (город, брачный статус и т.п.). Центральные тенденции второго можно смотреть при помощи моды. Будет некорректно задавать неупорядоченным категориям какой-то числовой порядок и смотреть средние арифметические. К средним каких-то ординальных показателей, или численных показателей, содержащих большое число значений, например возраста, надо относиться так, что это центр распределения, которое может иметь какую-то сложную природу. Бинарные показатели, если к ним применить среднее, показывают нам долю тех клиентов, у которых этот бинарный показатель равен единице.
#
# Уже на этапе подготовки данных важно закодировать данные численно. Для того, чтобы применять среднее и смотреть корреляции какого-то числового показателя с категориальным неупорядоченным, можно применить <a href='https://habr.com/ru/post/666234/'>one-hot кодирование</a>, проще всего это сделать при помощи <tt>pandas.get_dummies</tt>. Чтобы при этом не потерять оригинальный столбец, стоит сделать его копию и использовать параметр <tt>columns</tt> (чтобы перекодированию подвергся или подверглись только те столбцы, которые нам нужно перекодировать).</div>

# %% [markdown]
# #### Промежуточный вывод по предобработке данных

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
#
#
#     В процессе предобработки сделано и выявлено:
#
#         1. Переименованы столбцы 'USERID' - 'user_id' и 'EST_SALARY' - 'est_salary'.
#         2. Приведены типы полей 'score', 'age' к int64.
#         3. Изучена природа 23% пропусков в 'balance'. Выдвинута гипотеза, что данные пропуски связаны с отсутствием у клиентов дебетовых карт. Пропуски решено заменить на 0.
#         4. Удалены 26 записей с пропусками в поле 'age'.
#         5. Обработаны дубликаты в поле 'user_id'.
#         6. Удалена одна запись про клиента без продуктов банка.
#         7. Исследован срез по минимальным зарплатам - решено оставить как есть.
#
#     Данные предобработаны и готовы к анализу.
#
# </div>

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Анализ средних и медианных значений

# %%
# сравниваем средние значения отточных/неотточных

compare = pd.concat([round(df.describe()[1:2],2).T, round(df.groupby('churn').mean().T,2)], axis=1)
compare.columns = ('mean','not_churn','churn')

# %%
compare
# Out:
#                     mean  not_churn       churn
# user_id        171739.57  171907.06   170992.83
# score             848.72     845.44      863.36
# age                42.73      43.02       41.43
# equity              2.63       2.38        3.76
# balance        639662.69  530356.73  1126970.04
# products            1.87       1.76        2.38
# credit_card         0.68       0.71        0.55
# last_activity       0.52       0.48        0.70
# est_salary     147892.55  147788.27   148357.48
# churn               0.18        NaN         NaN
# debit_card          0.77       0.72        0.99
# female              0.50       0.53        0.35
# male                0.50       0.47        0.65
# Ростов              0.14       0.14        0.15
# Рыбинск             0.27       0.27        0.24
# Ярославль           0.59       0.58        0.61

# %%
#  добавим столбец процентных отличий отточных от неотточных

compare['delta, %'] = (100* (compare['not_churn'] - compare['churn']) / compare['not_churn']).abs().round()
compare.sort_values(by='delta, %', ascending=False)
# Out:
#                     mean  not_churn       churn  delta, %
# balance        639662.69  530356.73  1126970.04     112.0
# equity              2.63       2.38        3.76      58.0
# last_activity       0.52       0.48        0.70      46.0
# debit_card          0.77       0.72        0.99      38.0
# male                0.50       0.47        0.65      38.0
# products            1.87       1.76        2.38      35.0
# female              0.50       0.53        0.35      34.0
# credit_card         0.68       0.71        0.55      23.0
# Рыбинск             0.27       0.27        0.24      11.0
# Ростов              0.14       0.14        0.15       7.0
# Ярославль           0.59       0.58        0.61       5.0
# age                42.73      43.02       41.43       4.0
# score             848.72     845.44      863.36       2.0
# user_id        171739.57  171907.06   170992.83       1.0
# est_salary     147892.55  147788.27   148357.48       0.0
# ...

# %% [markdown]
# Тут у нас в первом столбце средние значения по всему датасету, во втором по клиентам, не ушедшим в отток, в третьем по отточным, в столбце 'delta, %  - процент отличий отточных от неотточных', на основании него можно сравнить средние портреты.
#
# Портреты средних пользователей отличаются по:
# 1. балансу - у отточных в среднем на балансе в 2 раза больше денег (более 1 млн. рублей)
# 2. оценке собственности - у отточных оценка собственности в среднем выше на 60%
# 3. активности - у отточные активность выше на 46%
# 4. полу - среди мужчин больше отточных, среди женщин больше неотточных
# 5. количеству продуктов - в среднем у отточных на треть больше продуктов
# 6. наличию кредитной карты - у отточных кредитная карта встречается реже на 23%.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Мы по таким показателям не можем ещё определить границу, когда преимущественно неотточные при изменении характеристики становятся преимущественно отточными, для этого нужно более подробное исследование. Да, скорее всего при достаточно простых распределениях мы ожидаем что точка, по которой мы сможем разделить преимущественно отточных от неотточных будет находиться между центральной тенденцией одних и других (т.е. между 530 тыс. 1.1 млн).
# </div><div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>
# Ты заметил не все имеющиеся различия. Пожалуйста, добавь столбец процентных отличий отточных от неотточных, отсортируй таблицу по нему и дополни выводы.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавил столбец 'delta, %' и обновил выводы. </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# Посмотрим медианные значения по аналогичной таблице.

# %%
# сравниваем медианные значения отточных/неотточных

pd.concat([round(df[['balance','est_salary']].describe()[5:6],2).T, round(df.groupby('churn')['balance','est_salary'].median().T,2)], axis=1)
# Out:
# /tmp/ipykernel_78/3053956304.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pd.concat([round(df[['balance','est_salary']].describe()[5:6],2).T, round(df.groupby('churn')['balance','est_salary'].median().T,2)], axis=1)
#                   50%          0          1
# balance     376840.57  321743.27  775399.47
# est_salary  119719.33  118247.25  125408.88

# %% [markdown]
# По медианным значениям разница еще менее очевидна. Посмотрим более детально на гистограммах.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;💡<br>
# Медианы для бинарных и категориальных считать не стоит. Для баланса и доходов они тут подходят, да.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;🔧<br>
# Нужно будет сравнить количественные портреты клиентов, т.е. показатели типичных клиентов (как анализ стат.гипотез на равенство средних, только без стат.методов, на глаз). Это значит взять подходящие средние тенденции и посчитать для каждой характеристики, на сколько процентов это число больше (меньше) у отточных по сравнению с неотточными. То, что будет менее 10% по модулю можно проверить стат.критерием для надёжности.
# </div>
#
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;📝<br>Важно, чтобы такая характеристика как пол нашла своё отражение в портрете пользователя.
#
# В случае, если портретов два, например портрет отточных и неотточных, то для <u>сравнения портретов</u> (центральные тенденции характеристик) будет очень удобно посчитать процентные отличия (насколько процентов больше значение признака у отточных по сравнению с неотточными) и, отранжировав по ним, сразу понять, какие характеристики точно значительно влияют на отток. Сам по себе портрет отточного клиента не даст маркетингу такой информации, как сравнение портретов.
#
# <small>В случае, если портретов больше, то можно смотреть на отношение стандартного отклонения .std() к (скорректированному на минимальное значение характеристики) матожиданию .mean() — величина должна быть одного масштаба для всех характеристик. У тех характеристик, которые слабо влияют на признак, по которому проводится разделение, эта величина должна быть мала.</small>
# </div>

# %% [markdown]
# #### Распределение признаков в разрезе оттока

# %% [markdown]
# ##### Кредитный рейтинг клиента

# %%
# Построение гистограм распределения признака для отточных/неотточных клиентов

plt.figure(figsize=(9, 4))
sns.histplot(df, x = 'score', hue = 'churn', stat = 'density', common_norm = False)
plt.xlim([600, 1000])
plt.ylabel('Плотность распределения')
plt.xlabel('Кредитный рейтинг')
plt.title('Распределение клиентов по кредитному рейтингу в разрезе оттока');
plt.show()

plt.figure(figsize=(12, 7))
df_score = df.assign(score = df.score.round(-1))
ax =sns.lineplot(
    data=df_score,
    x='score',y='churn',label="Score churn")
ax.axhline(df.churn.mean(),color='r',label="Overall churn")
plt.ylabel('Уровень оттока')
plt.xlabel('Кредитный рейтинг')
plt.title('Зависимость оттока от кредитного рейтинга')

ax2=ax.twinx()
df_score.groupby('score').agg({"user_id":"count"}).plot(lw=0.5,c='gray',ax=ax2)
ax.legend(); ax2.legend(loc=2);

# %% [markdown]
# Из банка не уходят клиенты с кредитным рейтингом до 700.
#
# По зависимости оттока от кредитного рейтинга можно сделать вывод, что большая вероятность попасть в отток у клиентов с рейтингом в диапазоне от 825 до 940 баллов. Максимум оттока при 850-880 баллов.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;👀<br>Это явно не процент ушедших клиентов в зависимости от их рейтинга.
#
# Я не понимаю, откуда студенты берут вот эту идею. Факт что она стала часто встречаться.
#
#     score = score[score['sum']==1]
#
# Не первый раз. Берём только шум (места где мало данных). Смысл этого действия мне никто рассказать не смог, поэтому я всегда подозревал заимствование откуда-то. Возможно ты объяснишь, зачем это делается? Ну либо укажешь источник (никаких негативных последствий, конечно, не будет).
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Заменил ошибочный график. Да, ошибка списана с чужого решения https://github.com/syuzannepetrosyan/churn_clients_banks/tree/main </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>🔬</big></b> спасибо за информацию!</div>

# %%
### КОД РЕВЬЮЕРА 
df_score = df.assign(score = df.score.round(-1))
ax =sns.lineplot(
    data=df_score,
    x='score',y='churn',label="Score churn")
ax.axhline(df.churn.mean(),color='r',label="Overall churn")

ax2=ax.twinx()
df_score.groupby('score').agg({"user_id":"count"}).plot(lw=0.5,c='gray',ax=ax2)
ax.legend(); ax2.legend(loc=2);

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>
# Неверные выводы.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Обновил вывод по кредитному рейтингу </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ##### Возраст клиента

# %%
# Построение гистограм распределения признака для отточных/неотточных клиентов

plt.figure(figsize=(9, 4))
sns.kdeplot(df.query('churn==0')['age'], label = 'Не отточные')
sns.kdeplot(df.query('churn==1')['age'], label = 'Отточные')
plt.legend()
plt.ylabel('Плотность распределения')
plt.xlabel('Возраст клиентов')
plt.title('Распределение клиентов по возрасту в разрезе оттока');
plt.show()

# Рассчитаем процент ушедших клиентов в разбивке по возрастным группам от общего числа:
age = df.pivot_table(index = 'age', values = 'churn', aggfunc =['sum', 'count'])
age.columns = ['sum', 'count']
age['ratio'] = age['sum']/age['count']*100

# Построим столбчатую диаграмму:
age['ratio'].plot(title = 'Процент ушедших клиентов во возрастам', color='darkorange',
    xlabel = 'Возраст клиентов', ylabel = 'Процент ушедших клиентов', figsize = (9,4))


plt.figure(figsize=(12, 7))

df_age = df.assign(age = df.age.round(-1))
ax =sns.lineplot(
    data=df_age,
    x='age',y='churn',label="Score churn")
ax.axhline(df.churn.mean(),color='r',label="Overall churn")

plt.ylabel('Уровень оттока')
plt.xlabel('Возраст')
plt.title('Зависимость оттока от возраста')

ax2=ax.twinx()
df_age.groupby('age').agg({"user_id":"count"}).plot(lw=0.5,c='gray',ax=ax2)
ax.legend(); ax2.legend(loc=2);

# %% [markdown]
# На графике выделяется явный лидер по оттоку - пользователи в возрасте от 45 до 60 лет,
# среди них почти 30% отточных. Чуть меньше (20% оттока) - у возрастной группы 22-35 лет.
# Минимальный показатель у пользователей старше 65 лет - отточных менее 5%.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>👍</big></b></div>

# %% [markdown]
# ##### Оценка объектов собственности

# %%
plt.figure(figsize=(9, 4))
sns.kdeplot(df.query('churn==0')['equity'], label = 'Не отточные')
sns.kdeplot(df.query('churn==1')['equity'], label = 'Отточные')
plt.legend()
plt.title('Распределение клиентов по оценкам собственности в разрезе оттока')
plt.xlabel('Оценка собственности')
plt.ylabel('Плотность распределения')
plt.show()

# Рассчитаем процент ушедших клиентов в разбивке по оценке принадлежащей им собственности от общего числа:

equity = df.pivot_table(index = 'equity', values = 'churn', aggfunc = ['sum', 'count'])
equity.columns = ['sum', 'count']
equity['ratio'] = equity['sum']/equity['count']*100

# Построим столбчатую диаграмму:
equity['ratio'].plot(
    kind='bar', title = 'Процент отточных клиентов в разбивке по оценке собственности',
    xlabel = 'Оценка собственности', ylabel = 'Процент ушедших клиентов', figsize = (9,4), color='darkorange')
plt.xticks(rotation=0)

plt.figure(figsize=(12, 7))
df_equity = df.assign(score = df.equity.round(-1))
ax =sns.lineplot(
    data=df_equity,
    x='equity',y='churn',label="Отток")
ax.axhline(df.churn.mean(),color='r',label="Средний отток по базе")
plt.title('Зависимость оттока от оценки собственности')
plt.xlabel('Оценка собственности')
plt.ylabel('Уровень оттока')

ax2=ax.twinx()
df_equity.groupby('equity').agg({"user_id":"count"}).plot(lw=0.5,c='gray',ax=ax2)
ax.legend(); ax2.legend(loc=2);

# %% [markdown]
# По графикам прослеживается прямая зависимость - чем выше оценка собственности, тем выше процент отточных клиентов.
# По графику распределения клиентов по оценкам собственности в разрезе оттока и зависимости уровня оттока от оценки собственности можно сделать выводы, что оценка 2,5 является точкой перехода, выше которой можно ожидать, что клиент вероятнее уйдет из банка.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Нужны более полные выводы. Начиная с какой оценки собственности мы можем ожидать что клиент более вероятно уйдёт из банка чем в среднем по банку?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавил график по аналогии с кредитным рейтингом, указал вывод более детально. </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ##### Баланс  клиента

# %%
plt.figure(figsize=(12, 7))
sns.kdeplot(df.query('churn==0')['balance'], label = 'Не отточные')
sns.kdeplot(df.query('churn==1')['balance'], label = 'Отточные')
plt.xlim([0, 4000000])
plt.legend()
plt.title('Распределение клиентов балансу в разрезе оттока')
plt.xlabel('Баланс')
plt.ylabel('Плотность распределения')
plt.show()

# %% [markdown]
# Клиенты с балансом выше 750.000 рублей чаще уходят в отток

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Тут на графике видим что распределения пересекаются где-то в 750 тыс. Можно применить .clip к данным чтобы получить более точный график и сделать более точную оценку.
# </div>

# %% [markdown]
# #####  Активность клиента

# %%
# процент ушедших клиентов в разбивке по активности от общего числа
activity_churn = df.pivot_table(index = 'last_activity', values = 'churn', aggfunc = ['sum', 'count'])
activity_churn.columns = activity_churn.columns.droplevel(level=1)
activity_churn ['perc'] = activity_churn['sum']/activity_churn['count']*100

# столбцовая диаграмма:
activity_churn['perc'].plot(
    kind='bar', title = 'Процент отточных клиентов в разбивке по активности', figsize = (9,4), 
    color='darkorange', ylabel = 'Процент отточных клиентов', xlabel = 'Активность клиента')
plt.xticks(rotation=0);

# %% [markdown]
# У активных клиентов процент оттока в 2 раза больше, чем у неактивных.

# %% [markdown]
# ##### Пол клиента

# %%
# процент отточных клиентов в разбивке по полу:

gender_churn = df.pivot_table (index = 'gender', values = 'churn', aggfunc = ['sum', 'count'])
gender_churn.columns = gender_churn.columns.droplevel(level=1)
gender_churn ['perc'] = gender_churn['sum']/gender_churn['count']*100

# столбцовая диаграмма

mylabels = ['Не были активны','Были активны']
gender_churn['perc'].plot(
    kind='bar', title = 'Процент ушедших клиентов в разбивке по полу', figsize = (9,4),
    xlabel = 'Пол', ylabel = 'Процент ушедших клиентов', color='darkorange',)
plt.xticks(rotation=0);

# %% [markdown]
# Мужчины уходят в отток в два раз чаще женщин.

# %% [markdown]
# ##### Наличие кредитной карты

# %%
# процент ушедших клиентов в разбивке по наличию кредитной карты:

credit_card_churn = df.pivot_table (index = 'credit_card', values = 'churn', aggfunc = ['sum', 'count'])
credit_card_churn.columns = credit_card_churn.columns.droplevel(level=1)
credit_card_churn ['perc'] = credit_card_churn['sum']/credit_card_churn['count']*100

# Построим круговую диаграмму:

credit_card_churn['perc'].plot(
    kind='bar', figsize = (9,4), xlabel = 'Наличие кредитной карты',
    title = 'Процент отточных клиентов в разбивке по по наличию кредитной карты',
    ylabel = 'Процент отточных клиентов', color='darkorange')
plt.xticks(rotation=0);

# %% [markdown]
# Клиенты с кредитной картой уходят в отток почти в два раза реже.

# %% [markdown]
# ##### Количество продуктов клиента

# %%
plt.figure(figsize=(9, 4))

sns.kdeplot(df.query('last_activity==0')['products'], label = 'Неактивные')
sns.kdeplot(df.query('last_activity==1')['products'], label = 'Активные')
plt.title('Распределение клиентов по количеству используемых продуктов в разрезе оттока')
plt.xlabel('Количество продуктов')
plt.ylabel('Плотность распределения')
plt.legend()
plt.show()


plt.figure(figsize=(12, 7))
df_products = df.assign(score = df.products.round(-1))
ax =sns.lineplot(
    data=df_products,
    x='products',y='churn',label="products churn")
ax.axhline(df.churn.mean(),color='r',label="Overall churn")
plt.ylabel('Уровень оттока')
plt.xlabel('Количество продуктов')
plt.title('Зависимость оттока от количества используемых продуктов')

ax2=ax.twinx()
df_products.groupby('products').agg({"user_id":"count"}).plot(lw=0.5,c='gray',ax=ax2)
ax.legend(); ax2.legend(loc=1);

# %% [markdown]
# Более 60% клиентов, использовавших 4 продукта, ушли из банка. При наличии двух продуктов и более клиенты вероятнее уходят в отток, чем в среднем по банку.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>✔️</big></b> Графики выше ок. Можно улучшить, добавив линию среднего уровня оттока по всему банку.</div><div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Начиная с какого числа продуктов клиенты начинают уходить в отток сильнее, чем в среднем по банку?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавил график по аналогии с кредитным рейтингом, указал вывод более детально. </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ##### Заработная плата

# %%
plt.figure(figsize=(12, 7))
sns.histplot(df, x = 'est_salary', hue = 'churn', stat = 'density', common_norm = False)
plt.xlim([0, 400000])
plt.title('Распределение клиентов по уровню зарплаты в разрезе оттока')
plt.xlabel('Зарплата, руб.')
plt.ylabel('Плотность распределения');

# %% [markdown]
# В целом по зарплате распределение отточных повторяет распределение неотточных. Некоторое разделение происходит в райорне 100 тысяч рублей. Зарабатывающие от 100.000 до 200.000 рублей более склонны к оттоку.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# А зарабатывающие более 220 тыс. сильнее склонны к оттоку, чем в среднем по банку?
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ##### Город

# %%
# процент ушедших клиентов в разбивке по городам:

city_churn = df.pivot_table (index = 'city', values = 'churn', aggfunc =['sum', 'count'])
city_churn.columns = city_churn.columns.droplevel(level=1)
city_churn ['perc'] = city_churn['sum']/city_churn['count']*100

city_churn['perc'].plot(
    kind='bar', title = 'Процент отточных клиентов в разбивке по городам',
    ylabel = 'Процент ушедших клиентов', figsize = (9,4), color='darkorange')
plt.xticks(rotation=0);

# %% [markdown]
# Отток клиентов между городами происходит равномерно - никакой город выделить нельзя.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;🔧<br>
# Необходимо будет изучить распределения характеристик в разрезе оттока. Просто распределения отточных не хватит. Если распределение отточных будет повторять распределение неотточных, значит отток от этой характеристики не зависит.
#
# Для непрерывных характеристик построить гистограммы или kde-графики, для категориальных — столбчатые диаграммы с уровнями оттока (количество отточных в категории, делённое на общее количество в категории).
# </div>
#
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;💡<br>
# По обычным гистограммам или sns.countplot графикам можно делать грубые выводы, но из-за необходимости делать поправки на разные размеры групп в уме, точных выводов по ним обычно не сделаешь. Нивелировать разницы в размерах групп можно если применить <tt>sns.kdeplot</tt> или <tt>sns.histplot</tt> с параметрами <tt>hue</tt> и настройками <tt>stat="density", common_norm=False</tt> (для kdeplot stat="density" не нужно, common_norm=False нужно именно при использовании hue). При использовании plt.hist и основанных на нём методах pandas достаточно установить параметр <tt>density=True</tt>, также понадобится установить прозрачность (цвета лучше подобрать так, чтобы было меньше затруднений от того, что они смешаются). Обращаю внимание, что метод <tt>sns.dis<b>t</b>plot</tt> является устаревшим и его нежелательно использовать.
#
# В px.histogram, если хочется использовать именно эту библиотеку, можно установить параметры <tt>histnorm='probability density',barmode ='overlay'</tt>.
#
# В целом гистограммы подходят для непрерывных переменных и переменных с большим числом уникальных значений. Если гистограмма "идёт лесенкой", это означает, что для дискретной переменной выбрано некратное количество корзин. Можно использовать параметр <tt>binwidth</tt>, но только для дискретных величин, не достигающих огромных значений (может приводить к зависанию ядра). Для анализа бинарных и категориальных признаков гистограммы не подходят.
#
# Для категориальных есть очень простой и действенный, а главное понятный и больше подходящий для презентации подход — можно делать сводные таблицы pivot_table с уровнем оттока по категориям (или сделать группировку по категории с последующей аггрегацией информации об оттоке) и из них столбиковые диаграммы со средним уровнем оттока по банку.
# </div>

# %% [markdown]
# #### Матрица корреляции

# %%
plt.figure(figsize=(7,7))
sns.heatmap(
    df.corr().loc[:,['churn']].drop('churn').sort_values('churn', ascending = False), 
    annot=True, fmt=".0%", cmap="BrBG", center=0
)
# Out:
# <AxesSubplot:>

# %%
# тепловая карта корреляции для всех столбцов

plt.figure(figsize=(15,7))
sns.heatmap (df.corr(), annot=True, fmt='.2g', vmin=-1, vmax=1, center= 0, cmap='BrBG');

# %% [markdown]
# Из матрицы видно, что наибольшая корреляция с показателем оттока у следующих параметров:
#
# 1. products - 30%
# 2. equity - 27%
# 3. last_activity - 17%
# 4. male/female - 14%
# 5. credit_card - 13%
# 5. balance - 13%
# 6. score - 11%
#
#
# В целом можно сказать, что сила коэффициента корреляции очень слабая (не больше 0.3). Следовательно, у нас нет очевидного признака, по которому мы могли бы явно выявить склонность клиентов к оттоку.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;📝<br>
# В презентации будет хорошо смотреться heatmap в один столбец (churn) из этой корреляционной матрицы, отсортированный по величине корреляции, но без самой строки (churn). Её можно убрать методом drop
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;🔧<br>
# Необходимо будет проанализировать все данные на предмет наличия корреляций с целевой характеристикой, описать всё, что превосходит по модулю 10% (это будет использоваться в дальнейшем в промежуточном итоге перед сегментацией), подготовить читаемый график (тепловую карту) для презентации.
# </div>
#
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;💡<br>
# Для корреляционных матриц стоит выбирать <a href='https://seaborn.pydata.org/tutorial/color_palettes.html'>цветовые схемы</a>, у которых по центру находится нейтральный цвет, а по краям — два явно различимых, например <tt>'vlag'</tt> (<tt>'coolwarm'</tt> также подходит) при этом установка для <a href='https://seaborn.pydata.org/generated/seaborn.heatmap.html'><tt>sns.heatmap<tt></a> симметричных относительно нуля параметров <tt>vmax</tt> и <tt>vmin</tt> или <tt>center = <b>0</b></tt> позволяет убедиться, что незначимые (близкие к нолю) значения будут обозначаться именно нейтральным цветом. Также стоит указывать параметр fmt, например, устанавливая отображение значений в виде процентов без дробной части.
#
# Для описания корреляций есть шкала Чеддока. Необходимо будет описать все корреляции характеристик с нашей целевой характеристикой.
#
# Могу посоветовать также <a href='https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7'>матрицу корреляций phic</a> — она улавливает даже нелинейные зависимости.
# </div>

# %% [markdown]
# #### Формирование портрета пользователя

# %% [markdown]
# На основании проведенного исследовательского анализа данных по результатам оценки распределения признаков в разрезе оттока и корреляционного анализа, сформулируем:
#
# признаки клиентов, которые склонны уходить в отток:
#
# 1. Имеющие 2 и более продукта
# 2. С оценкой собственности от 3
# 3. Активные
# 4. Мужчины
# 5. Без кредитной карты
# 6. Имеющие на балансе от 750.000 рублей
# 7. Со скоринговым рейтингом от 825 до 940 баллов
# 8. В одной из двух возрастных групп 22-35 или 45-60 лет
# 9. С заработной платой от 100 до 200 тысяч рублей
#
#
# признаки клиентов, которые склонны оставаться:
#
# 1. Скоринговый рейтинг ниже 825 баллов или более 950
# 2. Старше 60 лет
# 3. Низкая оценка собственности 0-2
# 4. Баланс менее 750.000 рублей
# 5. Неактивные
# 6. Преимущественно женщины
# 7. С кредитной картой
# 8. Малым количеством продуктов
# 9. С зарплатой менее 100 тысяч рублей

# %% [markdown]
# #### Промежуточный вывод по исследовательскому анализу данных

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
#
#
# 1. Очевидного признака, по которому мы могли бы явно выявить склонность клиентов к оттоку, нет.
#
# 2. Из матрицы корреляции видно, что наибольшая корреляция с показателем оттока у следующих параметров:
#
#         products - 30%
#         equity - 27%
#         last_activity - 17%
#         male/female - 14%
#         credit_card - 13%
#         balance - 13%
#         score - 11%
#
# 3. Портреты средних пользователей отличаются по следующим показателям:
#         1. балансу - у отточных в среднем на балансе в 2 раза больше денег (более 1 млн. рублей)
#         2. оценке собственности - у отточных оценка собственности в среднем выше на 60%
#         3. активности - у отточные активность выше на 46%
#         4. полу - среди мужчин больше отточных, среди женщин больше неотточных
#         5. количеству продуктов - в среднем у отточных на треть больше продуктов
#         6. наличию кредитной карты - у отточных кредитная карта встречается реже на 23%.
#
#
# 4. Большая вероятность попасть в отток у клиентов с рейтингом в диапазоне от 825 до 940 баллов. Максимум оттока при 850-880 баллов.
#
# 5. На графике выделяется явный лидер по оттоку - пользователи в возрасте от 45 до 60 лет, среди них почти 30% отточных. Чуть меньше (20% оттока) - у возрастной группы 22-35 лет. Минимальный показатель у пользователей старше 65 лет - отточных менее 5%.
#
# 6. По графикам прослеживается прямая зависимость - чем выше оценка собственности, тем выше процент отточных клиентов. Оценка 2,5 является точкой перехода, выше которой можно ожидать, что клиент вероятнее уйдет из банка
#
# 7. Клиенты с балансом выше 750.000 рублей чаще уходят в отток.
#
# 8. У активных клиентов процент оттока в 2 раза больше, чем у неактивных.
#
# 9. Мужчины уходят в отток в два раз чаще женщин.
#
# 10. Клиенты с кредитной картой уходят в отток почти в два раза реже.
#
# 11. Более 60% клиентов, использовавших 4 продукта, ушли из банка. При наличии двух продуктов и более клиенты вероятнее уходят в отток, чем в среднем по банку.
#
# 12. В целом по зарплате распределение отточных повторяет распределение неотточных. Некоторое разделение происходит в райорне 100 тысяч рублей. Зарабатывающие от 100.000 до 200.000 рублей более склонны к оттоку.
#
# 13. Отток клиентов между городами происходит равномерно - никакой город выделить нельзя.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>✔️</big></b> но по собственности не указано никакого точного числа</div>

# %% [markdown]
# ### Проверка статистических гипотез

# %%
# разделим датасет на отточный и неотточный для удобства
df_churn = df[(df['churn'] == 1)]
df_notchurn = df[(df['churn'] == 0)]

# %% [markdown]
# #### Гипотеза различия дохода между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# - H0: доход между теми клиентами, которые ушли и теми, которые остались не различается
# - H1: доход между теми клиентами, которые ушли и теми, которые остались различается

# %%
plt.figure(figsize=(9, 4))
sns.histplot(df, x = 'est_salary', hue = 'churn', stat = 'density', common_norm = False)
#plt.xlim([0, 400000])
plt.title('Распределение клиентов по уровню зарплаты в разрезе оттока')
plt.xlabel('Зарплата, руб.')
plt.ylabel('Плотность распределения');

# %%
# проверим распределение на нормальность тестом Шапиро-Уилка

alpha = 0.05  # критический уровень статистической значимости

results = st.shapiro(df.est_salary.sample(100))
p_value = results[1]
print('p-значение: ', p_value)

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: распределение не нормально')
else:
    print('Не получилось отвергнуть нулевую гипотезу, распределение нормально')
# Out:
# p-значение:  2.817661685569628e-12
# Отвергаем нулевую гипотезу: распределение не нормально

# %%
print(f"эксцесс равен {df.est_salary.kurt().round()}, асимметрия равна {df.est_salary.skew().round()}")
# Out:
# эксцесс равен 22.0, асимметрия равна 4.0

# %% [markdown]
# Распределение доходов имеет эксцесс равный 22, что сильно больше эксцесса нормального распределения (равен 3), а асимметрия положительная и равна 4.
#
# Это подтверждает выводы по результатам теста на нормальность. Распределение не нормлаьно, скошено в положительную сторону, и имеет больше значений в хвосте справа по сравнению с нормальным распределением.
#
# При работе с t-критерием всегда нужно удостовериться в нормальности распределения значений, при работе с небольшими совокупностями данных.

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# На основании этих выводов применим критерий Манна-Уитни, также применим t-критерий для сравниения результатов, но руководствоваться следует результатами по Манна-Уитни.

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 2</b>&nbsp;📌<br>
# Так как выборки большие, то нам неважно, что они распределены ненормально, мы можем использовать t-критерий. Требование нормальности распределения происходит из медицинской литературы, где традиционно маленькие выборки.
#
# <blockquote>Выборочные средние должны быть нормально распределены.
# А если выборка всего одна, то её среднее должно иметь нормальное распределение для разных выборок этого размера из определённой генеральной совокупности.
# Это условие не препятствие. Благодаря ЦПТ, если размер выборки составляет хотя бы несколько десятков значений, выборочные средние, которые можно получить из одной и той же генеральной совокупности, будут распределены нормально вокруг истинного среднего этой совокупности. Напомним, это утверждение верно, даже если сама генеральная совокупность не распределена нормально.
#
# Очень часто это условие путают с необходимостью нормального распределения самих генеральных совокупностей. Для корректного использования t-теста это необязательно.</blockquote>
# Таким образом нормальное распределение для выборок более 30-50 элементов не требуется для t-теста. Требуется отсутствие большого числа выбросов, так как это не робастный критерий. Но выбросы можно отфильтровать.
#
# При разном размере выборок, который нам тут известен мы ставим equal_var в положение False просто из-за особенностей работы метода ttest_ind. И вообще, надёжнее при любых сомнениях ставить его в это положение, это лишь немного снижает мощность данного стат критерия. В среднем у u-критерия Манна-Уитни мощность выше, чем у t-критерия, т.е. он чаще даёт более точный результат. В литературе встречаются утверждения, что его нельзя проводить, если есть значительное число повторяющихся значений или если выборки большие, однако это относится, видимо, к старым реализациям теста.
#
# Основной минус критерия Манна-Уитни — его слабая интерпретируемость для бизнеса. Если мы сраниваем суммы покупок, то t-критерий позволяет нам сравнить средний чек — величину, которую можно перевести в выручку, умножив на количество покупок. U-критерий же, по сути, будет сравнивать медианный чек, который практически не используется.
# </div>

# %% [markdown]
# Ввиду относительно небольшого объёма данных уровень статистической значимости при проверке статистических гипотез выберем равным 0.05.

# %% [markdown]
# ##### u-критерий Манна-Уитни

# %%
results = st.mannwhitneyu(df_churn['est_salary'], df_notchurn['est_salary'])

print('p-значение: ', results.pvalue.round(6))

if results.pvalue < 0.05:
    print('Отвергаем нулевую гипотезу: есть различие в зарплате между теми клиентами, которые ушли и теми, которые остались')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу: нет зарплате в доходе между теми клиентами, которые ушли и теми, которые остались'
    )
# Out:
# p-значение:  0.000203
# Отвергаем нулевую гипотезу: есть различие в зарплате между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# ##### t-критерий Стьюдента

# %%
results = st.ttest_ind(df_notchurn['est_salary'], df_churn['est_salary'], equal_var = False)

print (results.pvalue) 

if results.pvalue < 0.05:
    print ('Отвергаем нулевую гипотезу: есть различие в зарплате между теми клиентами, которые ушли и теми, которые остались')
else:
    print ('Не получилось отвергнуть нулевую гипотезу: нет различия в зарплате между теми клиентами, которые ушли и теми, которые остались')
# Out:
# 0.8626784591490475
# Не получилось отвергнуть нулевую гипотезу: нет различия в зарплате между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# Получили противоположенный результат - в данном случае стоит больше доверять u-критерию Манна-Уитни, т.к. распределение не нормально.
# Итого: отвергаем гипотезу о различии в доходах между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Пожалуйста проверь эти данные (доход клиентов) <a href='https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html'>статистическим тестом на нормальность</a>, посчитай методами <a href='https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.kurt.html'>kurt</a> (<a href='https://ru.wikipedia.org/wiki/Коэффициент_эксцесса'>эксцесс</a>) и <a href='https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.skew.html'>skew</a> (<a href='https://ru.wikipedia.org/wiki/Коэффициент_асимметрии'>асимметрия</a>) соответствующие значения, посмотри какие они должны быть у нормального распределения.
#
# Обязательно укажи, в каких случаях при работе с t-критерием нам нужно удостовериться в нормальности распределения значений в сравниваемых выборках и для чего это делается.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Проверил распределение на нормальность, посчитал эксцесс и асимметрию, обновил выводы. </div>

# %% [markdown]
# #### Гипотеза различия оценки собственности между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# - H0: оценка собственности между теми клиентами, которые ушли и теми, которые остались не различается
# - H1: оценка собственности между теми клиентами, которые ушли и теми, которые остались различается

# %% [markdown]
# Применим u-критерий Манна-Уитни, распределение не является нормальным

# %%
results = st.mannwhitneyu(df_churn['equity'], df_notchurn['equity'])

print('p-значение: ', results.pvalue)

if results.pvalue < 0.05:
    print('Отвергаем нулевую гипотезу: есть различие в оценке собственности между теми клиентами, которые ушли и теми, которые остались')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу: нет различия в оценке собственности между теми клиентами, которые ушли и теми, которые остались'
    )
# Out:
# p-значение:  1.4291024270306944e-156
# Отвергаем нулевую гипотезу: есть различие в оценке собственности между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# #### Гипотеза различия количества используемых банковских продуктов между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# - H0: среднее количество используемых банковских продуктов оставшихся и отточных клиентов равны
# - H1: среднее количество используемых банковских продуктов оставшихся и отточных клиентов не равны

# %%
results = st.mannwhitneyu(df_churn['products'], df_notchurn['products'])

print('p-значение: ', results.pvalue)

if results.pvalue < 0.05:
    print('Отвергаем нулевую гипотезу: есть различие в количестве продуктов, используемых теми клиентами, которые ушли и теми, которые остались')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу: нет различия в количестве продуктов, используемых между теми клиентами, которые ушли и теми, которые остались'
    )
# Out:
# p-значение:  7.674130300677304e-162
# Отвергаем нулевую гипотезу: есть различие в количестве продуктов, используемых теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера</b>&nbsp;✔️<br>
# Гипотезы сфомулированы верно, расчёты проведены и интерпретированы корректно
# </div><div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;⚠️<br>
# Самостоятельно сформулированные критерии не стоили того, чтобы их проверять. Мы и так были уверены в выводах по этим характеристикам.
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;📌<br>
# Так как тут можно самостоятельно выбирать инструментарий, то при проверках статистических гипотез необходимо обосновать выбор статистического критерия — перечислить все требования к данным, которые предъявляет этот критерий и проверить, соответствуют ли наши данные этим требованиям. Первую гипотезу, о том, влияет ли отток на доходы клиентов, необходимо проверить и t-критерием и u-критерием, объяснить расхождения, если они возникнут, выбрать, какому критерию стоит доверять сильнее. Т.к. необходимо понимать, когда следует применять t-критерий Стьюдента, а когда u-критерий Манна-Уитни, стоит описать, из-за чего между результатами работы критериев могут возникать расхождения, даже если они не возникли в данном случае.
#
# Также желательно, чтобы вторая, сформулированная вами гипотеза обоснованно требовала бы другого статистического критерия, либо проверка гипотезы была бы важна для выводов (касалась бы какой-то ситуации, когда на графиках видно небольшое различие и мы хотим подтвердить или опровергнуть свои выводы).
# </div>

# %% [markdown]
# #### Стратегические показатели

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
#
#     По итогам исследовательского анализа данных и проверке гипотез, можно выделить следующие стратегические показатели, влияющие на отток:
#
#     1. Активность клиентов
#     2. Мужской пол
#     3. Наличие двух и более продуктов
#     4. Оценка собственности 3 или больше
#     5. Отсутствие кредитной карты
#     6. Баланс от 750.000 рублей
#     7. Скоринговый рейтинг от 825 до 940
#     8. Возраст 22-35 или 45-60 лет
#     9. Доход от 100 до 200 тысяч рублей
#
# </div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🚫<br>Какой-то разнобой. Выше мы говорили баланс от миллиона. Теперь говорим от 500 тыс. Два отточных интервала по возрасту превратилось в один. Интервал по скору 825-900 почему-то исказился. У нас точно выводы от нашего проекта?
#
# По собственности все ещё неопределённо написано "высокая", какая — неясно. Больше или равно пяти, как ниже указано - слишком высокая. Клиенты с оценкой собственности 4 или 3 не отточны у нас?
#
# Мы можем сознательно брать не просто отточных, но суперотточных, чтобы сильнее уменьшать размер сегментов, но это должно делаться с аргументацией и указанием на то, что мы делаем.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Да, нашего, просто неточно перенёс выводы анализа. Сейчас поправил, буду внимательнее к цифрам.</div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %% [markdown]
# ### Сегментация на основе стратегических показателей

# %% [markdown]
# #### Выделение сегментов

# %% [markdown]
# ##### группа 1 - клиенты с 2 и более продуктами и оценкой собственности более 3

# %%
group_1 = df.query ('products >= 2 and equity >= 3') 
churns = (group_1.loc[group_1['churn'] == 1]['user_id'].count()/group_1.shape[0]*100).round(3)
print(f'Размер группы 1: {group_1.shape[0]}, уровень оттока {churns}%')
# Out:
# Размер группы 1: 4635, уровень оттока 28.393%

# %% [markdown]
# ##### группа 2 - активные мужчины без кредитной карты

# %%
group_2 = df.query ('male==1 and last_activity==1 and credit_card==0') 
churns = (group_2.loc[group_2['churn'] == 1]['user_id'].count()/group_2.shape[0]*100).round(2)
print(f'Размер группы 2: {group_2.shape[0]}, уровень оттока {churns}%')
# Out:
# Размер группы 2: 717, уровень оттока 42.12%

# %% [markdown]
# ##### группа 3 - женщины с высоким скоринговым рейтингом и минимум двумя продуктами

# %%
group_3 = df.query ('female==1 and score >= 825 and score <= 940 and products >= 2 and credit_card == 0') 
churns = (group_3.loc[group_3['churn'] == 1]['user_id'].count()/group_3.shape[0]*100).round(2)
print(f'Размер группы 3: {group_3.shape[0]}, уровень оттока {churns}%')
# Out:
# Размер группы 3: 1005, уровень оттока 28.96%

# %% [markdown]
# ##### группа 4 - мужчины с высокой зарплатой в возрасте 45-60 лет

# %%
group_4 = df.query ('male==1 and age >45 and age<60') 
churns = (group_4.loc[group_4['churn'] == 1]['user_id'].count()/group_4.shape[0]*100).round(2)
print(f'Размер группы 4: {group_4.shape[0]}, уровень оттока {churns}%')
# Out:
# Размер группы 4: 1088, уровень оттока 29.04%

# %% [markdown]
# ##### группа 5 - клиенты с балансом более 750 тысяч рублей, без кредитной карты, с доходом от 100 тысяч и более чем двумя продуктами

# %%
group_5 = df.query('balance >= 750000 and products >= 2 and credit_card==0 and est_salary >=100000') 
churns = (group_5.loc[group_5['churn'] == 1]['user_id'].count()/group_5.shape[0]*100).round(2)
print(f'Размер группы 5: {group_5.shape[0]}, уровень оттока {churns}%')
# Out:
# Размер группы 5: 850, уровень оттока 48.24%

# %% [markdown]
# ##### группа 6 - активные мужчины с высоким рейтингом

# %%
group_6 = df.query('male==1 and last_activity==1 and score >= 825 and score <= 940') 
churns = (group_6.loc[group_6['churn'] == 1]['user_id'].count()/group_6.shape[0]*100).round(2)
print(f'Размер группы 6: {group_6.shape[0]}, уровень оттока {churns}%')
# Out:
# Размер группы 6: 1404, уровень оттока 40.81%

# %% [markdown]
# ##### группа 7 - активные клиенты в возрасте 22-35 или 45-60 с оценкой собственности от 3 и выше, кредитным рейтингом 825-940

# %%
group_7 = df.query('((age >= 22 and age <= 35) or (age >= 45 and age <= 60)) and equity >=3 and score >= 825 and score <= 940 and last_activity==1') 
churns = (group_7.loc[group_7['churn'] == 1]['user_id'].count()/group_7.shape[0]*100).round(2)
print(f'Размер группы 7: {group_7.shape[0]}, уровень оттока {churns}%')
# Out:
# Размер группы 7: 1129, уровень оттока 57.31%

# %% [markdown]
# ##### группа 8 - активные мужчины с высоким балансом

# %%
group_8 = df.query ('male==1 and balance >= 750000 and last_activity==1') 
churns = (group_8.loc[group_8['churn'] == 1]['user_id'].count()/group_8.shape[0]*100).round(2)
print(f'Размер группы 8: {group_8.shape[0]}, уровень оттока {churns}%')
# Out:
# Размер группы 8: 705, уровень оттока 60.0%

# %% [markdown]
# ##### группа 9 - активные клиенты в возрасте 45-60 лет

# %%
group_9 = df.query ('last_activity==1 and age>=45 and age<= 60') 
churns = (group_9.loc[group_9['churn'] == 1]['user_id'].count()/group_9.shape[0]*100).round(2)
print(f'Размер группы 9: {group_9.shape[0]}, уровень оттока {churns}%')
# Out:
# Размер группы 9: 1351, уровень оттока 28.05%

# %% [markdown]
# #### Приоритизация сегментов

# %% [markdown]
# 1. группа 7 - активные клиенты в возрасте 22-35 или 45-60 с оценкой собственности от 3 и выше, кредитным рейтингом 825-940 - Размер группы 7: 1129, уровень оттока 57.31%
# 2. группа 8 - активные мужчины с высоким балансом - Размер группы 8: 705, уровень оттока 60.0%
# 3. группа 5 - клиенты с балансом более 750 тысяч рублей, без кредитной карты, с доходом от 100 тысяч и более чем двумя продуктами - Размер группы 5: 850, уровень оттока 48.24%

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;📌<br>
# Везде используется признак мужчин, это не очень хорошо, приводит к излишнему пересечению
# </div><div class="alert alert-warning"><b>Комментарий ревьюера</b>&nbsp;🔧<br>
# Нужно будет использовать признаки, которые бъются с выводами по графикам, чтобы не было разночтений.
#
# Попробовать подобрать сегменты чтобы код ниже выдавал результат получше.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Подобрал новые сегменты, обновил рекомендации</div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера 2&nbsp;<big>✔️</big></b></div>

# %%
qrys = (
    '((age >= 22 and age <= 35) or (age >= 45 and age <= 60)) and equity >=3 and score >= 825 and score <= 940 and last_activity==1',
    'male==1 and balance >= 750000 and last_activity==1',
    'balance >= 750000 and products >= 2 and credit_card==0 and est_salary >=100000')

### КОД РЕВЬЮЕРА
display(pd.concat([
    pd.DataFrame(df.query(q).agg({"churn":['mean','count']}).values,
                 columns=[q],
                 index=['Отток','Размер']).T 
    for q in qrys]).style.format("{:.1%}",subset=["Отток"])\
                   .format("{:_.0f}",subset=["Размер"]))

all_catched = pd.concat([df.query(q) for q in qrys])
all_churn = df.churn.sum()
catched = all_catched.drop_duplicates().churn.sum()
share_catched = catched / all_churn

if len(qrys) != 3:
    print('Результаты ниже некорректны, нужно 3 лучших сегмента')
    
if all_catched.shape[0] > 5000:
    print("Отдел маркетинга не сможет обработать такое количество клиентов")
elif all_catched.shape[0] > 3000:
    print("Отделу маркетинга будет сложно обработать такое количество клиентов, его эффективность снизится")
elif all_catched.shape[0] < 1000:
    print("Сегменты можно увеличить")

text_churn = f"{catched}/{all_churn} = {share_catched:.1%}"
if share_catched < 1/3:
    print(f"В сегменты попало недостаточное число отточных: {text_churn}")
elif share_catched < 1/2:
    print(f"В сегменты попало: {text_churn}")
elif share_catched < 2/3:
    print(f"Хороший результат, в сегменты попало: {text_churn}")
else:
    print(f"Прекрасный результат, в сегменты попало: {text_churn}")
# Out:
# <style  type="text/css" >
# </style><table id="T_4c59f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Отток</th>        <th class="col_heading level0 col1" >Размер</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c59f_level0_row0" class="row_heading level0 row0" >((age >= 22 and age <= 35) or (age >= 45 and age <= 60)) and equity >=3 and score >= 825 and score <= 940 and last_activity==1</th>
#                         <td id="T_4c59f_row0_col0" class="data row0 col0" >57.3%</td>
#                         <td id="T_4c59f_row0_col1" class="data row0 col1" >1_129</td>
#             </tr>
#             <tr>
#                         <th id="T_4c59f_level0_row1" class="row_heading level0 row1" >male==1 and balance >= 750000 and last_activity==1</th>
#                         <td id="T_4c59f_row1_col0" class="data row1 col0" >60.0%</td>
# ...

# %% [markdown]
# ### Выводы и рекомендации для отдела маркетинга

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
#
# 1. Проведен первичный анализ имеющихся данных о клиентах Метанпромбанка. Мы имеет датасет с 10000 записями о клиентах из трех городов ('Рыбинск' 'Ярославль' 'Ростов'), обоих полов, в возрасте от 18 до 86 лет, с указанием кредитного рейтинга по шкале 600-1000 единиц и оценкой собственности от 0 до 9, а также баланса и дохода в рублях, количества продуктов, отметки о наличии кредитной карты, активности и попадании в отток.
#
# 2. Данные предобработаны и подготовлены к анализу. Обращает на себя 23% пропусков в значениях баланса. Выдвинута гипотеза, что данные пропуски связаны с отсутствием у клиентов дебетовых карт. Пропуски решено заменить на 0. Стоит отдельно проверить не является ли это технической ошибкой.
#
# 3. Исследовательский анализ данных, показал, что:
#
#     - Очевидного признака, по которому мы могли бы явно выявить склонность клиентов к оттоку, нет.
#     - Из матрицы корреляции видно, что наибольшая корреляция с показателем оттока у количества продуктов и оценке собственности (products - 30%, equity - 27%, last_activity - 17%, male/female - 14%, credit_card - 13%, balance - 13%, score - 11%)
#     - Портреты средних пользователей отличаются по следующим показателям:
#         1. балансу - у отточных в среднем на балансе в 2 раза больше денег (более 1 млн. рублей)
#         2. оценке собственности - у отточных оценка собственности в среднем выше на 60%
#         3. активности - у отточные активность выше на 46%
#         4. полу - среди мужчин больше отточных, среди женщин больше неотточных
#         5. количеству продуктов - в среднем у отточных на треть больше продуктов
#         6. наличию кредитной карты - у отточных кредитная карта встречается реже на 23%.
#     - Большая вероятность попасть в отток у клиентов с рейтингом в диапазоне от 825 до 940 баллов. Максимум оттока при 850-880 баллов.
#     - На графике выделяется явный лидер по оттоку - пользователи в возрасте от 45 до 60 лет, среди них почти 30% отточных. Чуть меньше (20% оттока) - у возрастной группы 22-35 лет. Минимальный показатель у пользователей старше 65 лет - отточных менее 5%.
#     - По графикам прослеживается прямая зависимость - чем выше оценка собственности, тем выше процент отточных клиентов. Оценка 2,5 является точкой перехода, выше которой можно ожидать, что клиент вероятнее уйдет из банка
#     - Клиенты с балансом выше 750.000 рублей чаще уходят в отток.
#     - У активных клиентов процент оттока в 2 раза больше, чем у неактивных.
#     - Мужчины уходят в отток в два раз чаще женщин.
#     - Клиенты с кредитной картой уходят в отток почти в два раза реже.
#     - Более 60% клиентов, использовавших 4 продукта, ушли из банка. При наличии двух продуктов и более клиенты вероятнее уходят в отток, чем в среднем по банку.
#     - В целом по зарплате распределение отточных повторяет распределение неотточных. Некоторое разделение происходит в райорне 100 тысяч рублей. Зарабатывающие от 100.000 до 200.000 рублей более склонны к оттоку.
#     - Отток клиентов между городами происходит равномерно - никакой город выделить нельзя.
#
#
# 4. Проведен статистический анализ следующих гипотез:
#
#     - Гипотеза №1 о различии доходов оставшихся и отточных клиентов: Отвергаем гипотезу
#     - Гипотеза №2 о различии в оценке объектов собственности отточных и оставшихся клиентов: Отвергаем гипотезу
#     - Гипотеза №3 о различии в количестве используемых банковских продуктов оставшихся и отточных клиентов: Отвергаем гипотезу
#
# По итогам исследовательского анализа данных и проверке гипотез, можно выделить следующие стратегические показатели, влияющие на отток:
#
#         1. Активность клиентов
#         2. Мужской пол
#         3. Наличие двух и более продуктов
#         4. Оценка собственности 3 или больше
#         5. Отсутствие кредитной карты
#         6. Баланс от 750.000 рублей
#         7. Скоринговый рейтинг от 825 до 940
#         8. Возраст 22-35 или 45-60 лет
#         9. Доход от 100 до 200 тысяч рублей
#
#
# 5. На основе стратегических показателей проведена сегментация клиентов - выделено 10 групп и для каждой подсчтинан уровень оттока. Топ-3 наиболее интересных групп, на которых рекомендуется сфокусироваться:
#
#     1. группа 7 - активные клиенты в возрасте 22-35 или 45-60 с оценкой собственности от 3 и выше, кредитным рейтингом 825-940 - Размер группы 7: 1129, уровень оттока 57.31%
#
#     2. группа 8 - активные мужчины с высоким балансом - Размер группы 8: 705, уровень оттока 60.0%
#
#     3. группа 5 - клиенты с балансом более 750 тысяч рублей, без кредитной карты, с доходом от 100 тысяч и более чем двумя продуктами - Размер группы 5: 850, уровень оттока 48.24%
#
#
# 6. Рекомендации по группам:
#
#     группа 7:
#         1. предложить новые продукты по страхованию собственности
#         2. повысить кэшбек на товары и услуги категории активного образа жизни
#         3. предложить кредит на льготных условиях
#
#     группа 8:
#         1. провести акцию совместно со спортивными, туристическими и автомобильными магазинами
#         2. предложить актуальные инвестиционные программы и брокерские услуги
#         3. предложить программу лояльности совместно с туроператорами или авиакомпаниями
#
#     группа 3:
#         1. предложить скидки на обслуживание или программу лояльности, зависящие от количества продуктов
#         2. предложить кредитную карту на льготных условиях
#         3. внедрить элементы геймификации в мобильном приложении для управления всем продуктами
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success"><b>Комментарий ревьюера&nbsp;<big>✔️</big></b> рекомендации таргетированы и конкретны</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Обновил выводы</div>

# %% [markdown]
# <div class="alert alert-warning"><b>Комментарий ревьюера 0</b>&nbsp;📌<br>
# Рекомендации должны относиться к конкретному сегменту, имеющему какой-то общий размер и уровень оттока (быть таргетированными), учитывать особенности этого сегмента, быть конкретными (содержать описание каких-то конкретных действий: акций, мероприятий, новых продуктов или изменения старых и т.п.) а не содержать указания для отдела маркетинга кого-то опросить и провести исследование и т.п.
# </div><div class="alert alert-success"><b>Комментарий ревьюера 0</b>&nbsp;👍<br>
# Удачной работы над проектом!
# </div>

# %% [markdown]
# ![Молодец](https://i.gifer.com/embedded/download/EbNG.gif "Молодец!")

# %%
df.to_csv('C:\df.csv', index=False)
